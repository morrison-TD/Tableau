# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
sept_data_to_load = "Resources/JC-201809-citibike-tripdata.csv"
oct_data_to_load = "Resources/JC-201810-citibike-tripdata.csv"
nov_data_to_load = "Resources/JC-201811-citibike-tripdata.csv"


# Read School and Student Data File and store into Pandas Data Frames
sept_data = pd.read_csv(sept_data_to_load)
oct_data = pd.read_csv(oct_data_to_load)
nov_data = pd.read_csv(nov_data_to_load)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1           370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2          1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3           383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4           377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3267        Morris Canal
# ...

# %%
sept_data.count
# Out:
# <bound method DataFrame.count of        tripduration                 starttime                  stoptime  \
# 0               284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1               370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2              1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3               383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4               377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
# ...             ...                       ...                       ...
# 39017           985  2018-09-29 09:02:31.3090  2018-09-29 09:18:56.6570
# 39018          1595  2018-09-30 09:36:44.8650  2018-09-30 10:03:19.9750
# 39019          1996  2018-09-30 11:15:46.8100  2018-09-30 11:49:03.1200
# 39020          1803  2018-09-30 11:16:37.0760  2018-09-30 11:46:40.6460
# 39021           779  2018-09-30 13:49:47.3930  2018-09-30 14:02:46.7200
#
#        start station id start station name  start station latitude  \
# ...

# %%
oct_data.count
# Out:
# <bound method DataFrame.count of        tripduration                 starttime                  stoptime  \
# 0               152  2018-10-01 07:44:41.4170  2018-10-01 07:47:14.2960
# 1               122  2018-10-01 08:50:05.4340  2018-10-01 08:52:08.2250
# 2               211  2018-10-01 09:03:17.0640  2018-10-01 09:06:48.0940
# 3               342  2018-10-01 10:13:07.0090  2018-10-01 10:18:49.8960
# 4              2976  2018-10-01 10:45:14.2800  2018-10-01 11:34:51.2610
# ...             ...                       ...                       ...
# 39133          1118  2018-10-31 11:30:53.7070  2018-10-31 11:49:32.4850
# 39134          1242  2018-10-31 12:20:41.6990  2018-10-31 12:41:24.4270
# 39135          1188  2018-10-31 12:21:36.2790  2018-10-31 12:41:24.3540
# 39136           983  2018-10-31 14:27:59.9590  2018-10-31 14:44:23.2020
# 39137           544  2018-10-31 15:37:41.3760  2018-10-31 15:46:45.5090
#
#        start station id start station name  start station latitude  \
# ...

# %%
nov_data.count
# Out:
# <bound method DataFrame.count of        tripduration                 starttime                  stoptime  \
# 0              1188  2018-11-01 06:32:27.5190  2018-11-01 06:52:15.9140
# 1               278  2018-11-01 07:14:31.8680  2018-11-01 07:19:10.2610
# 2               115  2018-11-01 07:33:17.1920  2018-11-01 07:35:12.2830
# 3               155  2018-11-01 08:20:10.9320  2018-11-01 08:22:46.7050
# 4                82  2018-11-01 08:35:02.7850  2018-11-01 08:36:25.1840
# ...             ...                       ...                       ...
# 24905           734  2018-11-28 10:46:12.6640  2018-11-28 10:58:27.0750
# 24906           312  2018-11-28 19:52:40.1140  2018-11-28 19:57:52.9270
# 24907           914  2018-11-29 10:20:57.7240  2018-11-29 10:36:12.0420
# 24908          2392  2018-11-29 17:28:24.1590  2018-11-29 18:08:16.8720
# 24909           637  2018-11-30 12:00:10.4100  2018-11-30 12:10:48.0210
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Combine the data into a single dataset


first_quarter=pd.concat([sept_data, oct_data, nov_data], keys=['sept_data', 'oct_data', 'nov_data'])
first_quarter.head()
# Out:
#              tripduration                 starttime                  stoptime  \
# sept_data 0           284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
#           1           370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
#           2          1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
#           3           383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
#           4           377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
#
#              start station id start station name  start station latitude  \
# sept_data 0              3183     Exchange Place               40.716247
#           1              3183     Exchange Place               40.716247
#           2              3183     Exchange Place               40.716247
#           3              3183     Exchange Place               40.716247
#           4              3183     Exchange Place               40.716247
#
# ...

# %%
first_quarter.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
first_quarter.to_csv('/QuarterData.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-23-d7fd683b6558> in <module>
# ----> 1 first_quarter.to_csv('/QuarterData.csv')
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ...

# %%
wrestled_over_hundred = wrestled_over_hundred.set_index("Start_Station")

wrestled_over_hundred.head()
